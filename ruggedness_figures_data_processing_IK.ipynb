# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

# Limit memory usage to 50% (adjust as needed)
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = "0.7"


import pickle
import numpy as np
import jax
import jax.numpy as jnp
import jax.random as jr
import matplotlib.pyplot as plt
from direvo_functions import *
from ruggedness_functions import *
import selection_function_library as slct
import tqdm
from scipy.optimize import curve_fit
import pandas as pd

# %%
# Define the SLIDE_data path
slide_data_dir = "/home/jess/Documents/SLIDE_data"

# %%
# The DE function

def directedEvolution(rng,
                      selection_strategy, 
                      selection_params, 
                      empirical = False, 
                      N = None, 
                      K = None, 
                      landscape = None, 
                      popsize=100, 
                      mut_chance=0.01, 
                      num_steps=50, 
                      num_reps=10, 
                      define_i_pop=None, 
                      pre_optimisation_steps=0,
                      average=True):
    
 
    r1,r2,r3=jr.split(rng,3)

    # Get initial population.
    if define_i_pop == None:
        i_pop = jnp.array([jr.randint(r1, (N,), 0, 2)]*popsize)
    else:
        i_pop = define_i_pop
 
    # Function for evaluating fitness.
    if empirical:
        fitness_function = build_empirical_landscape_function(landscape)
        mutation_function = build_mutation_function(mut_chance, 20)
    else:
        fitness_function = build_NK_landscape_function(r2, N, K)
        mutation_function = build_mutation_function(mut_chance, 2)
 
    # Define selection function.
    selection_function = build_selection_function(
        selection_strategy, selection_params)
    
    if pre_optimisation_steps!= 0:

        pre_op_selection_function=build_selection_function(slct.base_chance_threshold_select, {'base_chance':0.0, 'threshold':0.95})


        pre_op = run_directed_evolution(r3, i_pop=i_pop, 
                               selection_function=pre_op_selection_function, 
                               mutation_function=mutation_function, 
                               fitness_function=fitness_function, 
                               num_steps=pre_optimisation_steps)[1]
 
        i_pop = pre_op['pop'][-1]

    # Bringing it all together.
    vmapped_run = jax.jit(jax.vmap(lambda r: run_directed_evolution(
        r, i_pop, selection_function, mutation_function, fitness_function=fitness_function, num_steps=num_steps)[1]))
    
    # The array of seeds we will take as input.
    rng_seeds = jr.split(r3, num_reps)
    results = vmapped_run(rng_seeds)
 
    return results

# %% [markdown]
# ## NK Ruggedness Prediction

# %%
def NK_grid(N_range, num_samples=10):
    N = jnp.linspace(N_range[0], N_range[1], num=num_samples)
    K = jnp.array([jnp.linspace(1, i, num_samples)
                  for i in N]).reshape(num_samples, num_samples)
    N = jnp.repeat(N, num_samples).reshape(num_samples, num_samples)
    return N, K

N_grid, K_grid = NK_grid([10, 50])

Ns, Ks = N_grid.flatten(), K_grid.flatten()
Ns = jnp.flip(Ns)
Ks = jnp.flip(Ks)
NKs = list(zip(Ns,Ks))
# Out:
# 2026-03-16 10:14:44.588635: W external/xla/xla/service/gpu/nvptx_compiler.cc:836] The NVIDIA driver's CUDA version is 12.2 which is older than the PTX compiler version (12.6.20). Because the driver is older than the PTX compiler version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %%
## Large sweep data

file_path = os.path.join(slide_data_dir, "large_strategy_sweep.pkl")
with open(file_path, "rb") as f:
    strategy_data = pickle.load(f)

file_path = os.path.join(slide_data_dir, "large_decay_curve_sweep.pkl")
with open(file_path, "rb") as f:
    decay_data = pickle.load(f)

# %% [markdown]
# ### Example fitness decay curves

# %%
NK_pair = [(20,14), (20,1)]
#NK_pair = [(40,15), (40,2)]
out = []
params = {'threshold': 0.0, 'base_chance' : 1.0}
for nk in NK_pair:
    run = directedEvolution(jr.PRNGKey(0),
                            N = int(nk[0]),
                            K=int(nk[1]),
                            selection_strategy=slct.base_chance_threshold_select,
                            selection_params = params,
                            popsize=int(300),#int(150),
                            mut_chance=0.5/int(nk[0]),#0.1/int(nk[0]),
                            num_steps=25,
                            num_reps=1,
                            pre_optimisation_steps=20,
                            average=True)
    out.append(run['fitness'].mean(axis=-1))

smooth_rugged = np.array([out[i][0]/out[i][0][0] for i in range(2)]) # Normalising to decay from 1
smooth_rugged_decay_rates = np.array([get_single_decay_rate(i, mut = 0.5) for i in smooth_rugged])
mutations = np.linspace(0.0,12,25)
fitted_lines = np.array([( np.exp(-mutations*(i[0]))*(1 - i[-1]) + i[-1]) for i in smooth_rugged_decay_rates])
# Out:
# 2026-03-11 08:53:49.095883: W external/xla/xla/service/gpu/nvptx_compiler.cc:836] The NVIDIA driver's CUDA version is 12.2 which is older than the PTX compiler version (12.6.20). Because the driver is older than the PTX compiler version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %%
with open('plot_data/smooth_rugged_example.pkl', 'wb') as f:
    # pickle.dump((smooth_rugged, fitted_lines), f)

# %% [markdown]
# ### Ruggedness prediction accuracy over $K/N$

# %%
reshaped_decay_curves = decay_data.reshape(100,-1,25)
normalized_decay_curves = reshaped_decay_curves / reshaped_decay_curves[:, :, 0][:, :, np.newaxis]

# %%
decay_rates = np.zeros((normalized_decay_curves.shape[0], normalized_decay_curves.shape[1]))

for i in range(normalized_decay_curves.shape[0]):
    for ii in range(normalized_decay_curves.shape[1]):
        decay_rates[i,ii] = get_single_decay_rate(normalized_decay_curves[i,ii,:], mut=0.5)[0]

# %%
k_plus_one_over_ns = np.clip((np.array(NKs)[:,1] + 1)/np.array(NKs)[:,0], 0, 1)
k_over_ns = np.clip((np.array(NKs)[:,1])/np.array(NKs)[:,0], 0, 1)

# %%
with open('plot_data/ruggedness_accuracy.pkl', 'wb') as f:
    # pickle.dump((k_plus_one_over_ns, decay_rates), f)

# %% [markdown]
# ### Exploring accuracy over popsize

# %%
file_path = os.path.join(slide_data_dir, "popsize_accuracy.pkl")
with open(file_path, "rb") as f:
    popsize_data = pickle.load(f)

# %%
reshaped_popsize_curves = popsize_data.reshape(25,-1,25)
popsize_curves = reshaped_popsize_curves / reshaped_popsize_curves[:,:, 0][:, :, np.newaxis]

# %%
popsize_decay_rates = np.zeros((25,500))
for i in range(25):
    for ii in range(500):
        popsize_decay_rates[i,ii] = get_single_decay_rate(popsize_curves[i,ii,:], mut=1.0)[0]

pops=np.linspace(100,2500,25, dtype=int)

# %%
with open('plot_data/popsize_accuracy.pkl', 'wb') as f:
    # pickle.dump((popsize_decay_rates, pops), f)

# %% [markdown]
# ### Exploring accuracy over mutation rate

# %%
file_path = os.path.join(slide_data_dir, "mutation_rate_accuracy.pkl")
with open(file_path, "rb") as f:
    mut_data = pickle.load(f)

# %%
reshaped_mut_curves = mut_data.reshape(25,-1,25)
mut_curves = reshaped_mut_curves / reshaped_mut_curves[:,:, 0][:, :, np.newaxis]

# %%
muts=np.linspace(0.01,2,25)

mut_decay_rates = np.zeros((25,500))
for i in range(25):
    for ii in range(500):
        mut_decay_rates[i,ii] = get_single_decay_rate(mut_curves[i,ii,:], mut=muts[i])[0]

# %%
with open('plot_data/mut_accuracy.pkl', 'wb') as f:
    # pickle.dump((mut_decay_rates, muts), f)

# %% [markdown]
# ### Comparison of ruggedness metrics on NK

# %%
test_NKs = np.array([[12,0],[12,1],[12,2],[12,3],[12,4],[12,5],[12,6],[12,7],[12,8],[12,9],[12,10],[12,11]])
shape = (2,) * int(test_NKs[0][0])
NK_roughness_to_slope = []
NK_fourier = []
convergence_rates = []
convergence_rates_extra = []
NK_paths_to_max = []
NK_closest_max = []
NK_local_epistasis = []
rng = jr.PRNGKey(42)
rng_list = jr.split(rng, 50)

for N, K in test_NKs:
    print(N, K)
    for r in tqdm.tqdm(rng_list):
        N = int(N)
        K = int(K)
        complete_landscape = get_nk_l_o_shape(r, N, K,shape)
        NK_roughness_to_slope.append(roughness_to_slope(complete_landscape))
        NK_fourier.append(landscape_r2(complete_landscape))
        NK_paths_to_max.append(get_mean_paths_to_max(complete_landscape, norm=False, extra_slack = 0))
        NK_closest_max.append(1/find_distance_to_closest_max(complete_landscape))
        NK_local_epistasis.append(local_epistasis(complete_landscape,[0,]*12)), 
        cr, extr = get_convergence_rate(r, N, K, num_reps=100)
        convergence_rates.append(cr)
        convergence_rates_extra.append(extr)
# Out:
# 12 0
# 100%|██████████| 50/50 [03:56<00:00,  4.72s/it]
# 12 1
# 100%|██████████| 50/50 [03:24<00:00,  4.09s/it]
# 12 2
# 100%|██████████| 50/50 [03:17<00:00,  3.94s/it]
# 12 3
# 100%|██████████| 50/50 [03:17<00:00,  3.95s/it]
# 12 4
# 100%|██████████| 50/50 [03:30<00:00,  4.22s/it]
# 12 5
# 100%|██████████| 50/50 [03:29<00:00,  4.19s/it]
# 12 6
# 100%|██████████| 50/50 [03:28<00:00,  4.17s/it]
# 12 7
# 100%|██████████| 50/50 [03:25<00:00,  4.11s/it]
# 12 8
# 100%|██████████| 50/50 [03:21<00:00,  4.04s/it]
# 12 9
# 100%|██████████| 50/50 [03:22<00:00,  4.05s/it]
# 12 10
# 100%|██████████| 50/50 [03:19<00:00,  4.00s/it]
# 12 11
# 100%|██████████| 50/50 [03:48<00:00,  4.57s/it]

# %%
# Reshaping
NK_roughness_to_slope_r = np.array(NK_roughness_to_slope).reshape(12,50)
NK_fourier_r = np.array(NK_fourier).reshape(12,50)
convergence_rates_r = np.array(convergence_rates).reshape(12,50)
NK_paths_to_max_r = np.array(NK_paths_to_max).reshape(12,50)
NK_closest_max_r = np.array(NK_closest_max).reshape(12,50)
NK_local_epistasis_r = np.array([i['simple_sign_episasis'] + i['reciprocal_sign_epistasis'] for i in NK_local_epistasis]).reshape(12,50)

# %%
mean_NK_roughness_to_slope = [np.array(i).mean() for i in NK_roughness_to_slope_r]
mean_NK_fourier = [np.array(i).mean() for i in NK_fourier_r]
mean_convergence_rates = [np.array(i).mean() for i in  convergence_rates_r]
#mean_convergence_rates_extra = [np.array(i).mean() for i in convergence_rates_extra]
mean_NK_paths_to_max = [np.array(i).mean() for i in NK_paths_to_max_r]
mean_NK_closest_max = [np.array(i).mean() for i in NK_closest_max_r]
mean_NK_local_epistasis = [np.array(i).mean() for i in NK_local_epistasis_r]

# %%
mean_NK_closest_max = 1 - 1/np.array(mean_NK_closest_max)

# %%
def norm_data(data):
    return np.array(( data- min(data) )/( max(data)-min(data) ))

mean_NK_roughness_to_slope = norm_data(np.array(mean_NK_roughness_to_slope))
mean_NK_fourier = norm_data(np.array(mean_NK_fourier))
mean_NK_convergence_rates = norm_data(np.array(mean_convergence_rates))
mean_NK_paths_to_max = norm_data(np.array(mean_NK_paths_to_max))
mean_NK_closest_max = norm_data(np.array(mean_NK_closest_max))
mean_NK_le_normed = norm_data(np.array(mean_NK_local_epistasis))


k_over_ns = (test_NKs[:,1]+1)/test_NKs[:,0]

# %%
with open('plot_data/NK_ruggedness_metric_comparison.pkl', 'wb') as f:
    # pickle.dump((mean_NK_roughness_to_slope, mean_NK_fourier, mean_NK_convergence_rates, mean_NK_paths_to_max, mean_NK_closest_max, k_over_ns, mean_NK_le_normed), f)

# %% [markdown]
# ## Empirical ruggedness prediction

# %% [markdown]
# ### Comparison of ruggedness metrics on real landscapes

# %%
with open('landscape_arrays/GB1_landscape_array.pkl', 'rb') as f:
    GB1 = pickle.load(f)

with open('landscape_arrays/E3_landscape_array.pkl', 'rb') as f:
    ParD3 = pickle.load(f)

with open('landscape_arrays/TEV_landscape_array.pkl', 'rb') as f:
    TEV = pickle.load(f)

with open('landscape_arrays/TrpB_landscape_array.pkl', 'rb') as f:
    TrpB = pickle.load(f)

# %%
empirical_landscapes = [GB1, TrpB, TEV, ParD3]

# %%
# Decay rate

with open(os.path.join(slide_data_dir, "decay_curves_gb1_m0.1_multistart_10000_uniform.pkl"), "rb") as f:
    gb1_decay = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_trpb_m0.1_multistart_10000_uniform.pkl"), "rb") as f:
    trpb_decay = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_tev_m0.1_multistart_10000_uniform.pkl"), "rb") as f:
    tev_decay = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_pard3_m0.1_multistart_10000_uniform.pkl"), "rb") as f:
    pard3_decay = pickle.load(f)

decay_rate_measurements = [(i**2).mean(axis=(0,1,2)) for i in [gb1_decay, trpb_decay, tev_decay, pard3_decay]]
decay_rate_measurements = [i/i[0] for i in decay_rate_measurements]
decay_rate_measurements = [get_single_decay_rate(i)[0]/2 for i in decay_rate_measurements]

# %%
# Roughness to slope
roughness_to_slope_measurements  = [roughness_to_slope(i) for i in empirical_landscapes]

# %%
# Landscape R2
landscape_r2_measurements = [1-landscape_r2(i) for i in empirical_landscapes]

# %%
# Local epistasis
starting_points = [[3,17,0,3],[3,8,3,18],[19,17,11,18],[17,12,16]]
landscapes_and_starts = list(zip(empirical_landscapes,starting_points))
local_epistasis_measurements = [local_epistasis(i, np.array(ii)) for i, ii in landscapes_and_starts]

# %%
# Paths to global maximum
paths_to_max_measurements = [get_mean_paths_to_max(i, norm=False) for i in empirical_landscapes]
paths_to_max_measurements[3] = paths_to_max_measurements[3]*(max_possible_paths(GB1.shape)/max_possible_paths(ParD3.shape))

# %%
# Distance to closest local maximum
local_max_measurements = [find_distance_to_closest_max(i) for i in empirical_landscapes]

# %%
with open('plot_data/empirical_ruggedness_metric_comparison.pkl', 'wb') as f:
    # pickle.dump((decay_rate_measurements, roughness_to_slope_measurements, landscape_r2_measurements, local_epistasis_measurements, paths_to_max_measurements, local_max_measurements), f)

# %% [markdown]
# ### Fourier spectra of empirical landscapes

# %%
full_spectrum_gb1 = get_landscape_spectrum(GB1, remove_constant= False, on_gpu=True, norm = False) ## Changed from norm=True
full_spectrum_trpb = get_landscape_spectrum(TrpB, remove_constant= False, on_gpu=True, norm = False)
full_spectrum_tev = get_landscape_spectrum(TEV, remove_constant= False, on_gpu=True, norm = False)
full_spectrum_pard3 = get_landscape_spectrum(ParD3, remove_constant= False, on_gpu=True, norm = False)

with open('plot_data/fourier_spectra_empirical.pkl', 'wb') as f:
    # pickle.dump((full_spectrum_gb1 , full_spectrum_trpb, full_spectrum_tev, full_spectrum_pard3),f)

# %% [markdown]
# ### Landscape heterogeneity vs NK

# %%
with open(os.path.join(slide_data_dir, "N4A20_heterogeneity.pkl"), "rb") as f:
    NK_heterogeneity = pickle.load(f)

# %%
NK_heterogeneity = np.array([i.reshape(-1,25) for i in NK_heterogeneity])
empirical_heterogeneity = np.array([i.reshape(-1,25) for i in [gb1_decay, trpb_decay, tev_decay, pard3_decay]])

# %%
import random
NK_rhos = [[get_single_decay_rate(NK_heterogeneity[ii][i]**2)[0]/2 for i in random.sample(range(1, 100001), 1000)] for ii in range(4)]

# %%
import numpy as np
import random

eps = 1e-8
empirical_rhos = []

for ii in range(4):
    rhos_ii = []
    #for i in random.sample(range(100000), 1000):
    for i in range(10000):
        x = empirical_heterogeneity[ii][i]
        x = np.clip(x, eps, None)
        x = x**2
        x = x/x[0] 
        rho = get_single_decay_rate(x)[0]/2
        rhos_ii.append(rho)
    empirical_rhos.append(rhos_ii)

# %%
with open('plot_data/heterogeneity_data_IK.pkl','wb') as f:

    # pickle.dump((NK_rhos, empirical_rhos),f)

# %% [markdown]
# ### Popsize effects

# %%
popsizes = np.linspace(25,2500,10)

with open(os.path.join(slide_data_dir, "decay_curves_GB1_m0.1_multistart_10000_uniform_multi_popsize.pkl"), "rb") as f:
    GB1_popsize = pickle.load(f)

with open(os.path.join(slide_data_dir, "decay_curves_TrpB_m0.1_multistart_10000_uniform_multi_popsize.pkl"), "rb") as f:
    TrpB_popsize = pickle.load(f)

with open(os.path.join(slide_data_dir, "decay_curves_TEV_m0.1_multistart_10000_uniform_multi_popsize.pkl"), "rb") as f:
    TEV_popsize = pickle.load(f)

with open(os.path.join(slide_data_dir, "decay_curves_ParD3_m0.1_multistart_10000_uniform_multi_popsize.pkl"), "rb") as f:
    ParD3_popsize = pickle.load(f)

# %%
for i in GB1_popsize.mean(axis=(1,2,3)):
    get_single_decay_rate(i)

# %% [markdown]
# ## Sub-sampling accuracy

# %%
trajectories = np.round(np.logspace(0,5,6))

# %%
with open(os.path.join(slide_data_dir, "decay_curves_gb1_m0.1_multistart_10000_uniform.pkl"), "rb") as f:
    gb1_decay = pickle.load(f)
    print(gb1_decay.shape)
    
with open(os.path.join(slide_data_dir, "decay_curves_gb1_m0.1_all_starts.pkl"), "rb") as f:
    pard3_decay = pickle.load(f)
    print(pard3_decay.shape)
# Out:
# (100, 100, 10, 25)
# (1600, 100, 10, 25)

# %%
with open(os.path.join(slide_data_dir, "decay_curves_gb1_m0.1_all_starts.pkl"), "rb") as f:
    gb1_decay = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_trpb_m0.1_all_starts.pkl"), "rb") as f:
    trpb_decay = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_tev_m0.1_all_starts.pkl"), "rb") as f:
    tev_decay = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_pard3_m0.1_all_starts.pkl"), "rb") as f:
    pard3_decay = pickle.load(f)
    
with open(os.path.join(slide_data_dir, "decay_curves_gb1_m0.1_all_starts_IK_seed10.pkl"), "rb") as f:
    gb1_decay_v2 = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_trpb_m0.1_all_starts_IK_seed10.pkl"), "rb") as f:
    trpb_decay_v2 = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_tev_m0.1_all_starts_IK_seed10.pkl"), "rb") as f:
    tev_decay_v2 = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_pard3_m0.1_all_starts_IK_seed10.pkl"), "rb") as f:
    pard3_decay_v2 = pickle.load(f)

tot_steps = gb1_decay.shape[-1]
tot_reps = gb1_decay.shape[-2]
# empirical_locality = {
#     nm: decay.reshape(-1,tot_reps,tot_steps) 
#     for nm, decay in zip(["gb1", "trpb", "tev", "pard3"], [gb1_decay, trpb_decay, tev_decay, pard3_decay],strict=True)
# }
# # this gives per ld arrays: num_genotypes x num_reps x num_steps
empirical_heterogeneity = {
    nm: np.concatenate(
        [
            decay.reshape(-1, tot_reps, tot_steps),
            decay_v2.reshape(-1, tot_reps, tot_steps)
        ],
        axis=1  # concatenate along reps axis
    )
    for nm, decay, decay_v2 in zip(["gb1", "trpb", "tev", "pard3"], 
                         [gb1_decay, trpb_decay, tev_decay, pard3_decay],
                         [gb1_decay_v2, trpb_decay_v2, tev_decay_v2, pard3_decay_v2],
                         strict=True)
}
# this gives per ld arrays: num_genotypes x 2*num_reps x num_steps
tot_reps *= 2

# %%
titlesize = 10
labelsize = 8
ticksize = 6
legendsize = 8
dpi = 350
plt.rcParams["font.family"] = "DejaVu Sans"
c2 = 'tab:blue'#298c8c'
c1 = 'tab:orange' #800074'
c3 = '#f55f74'
c4 = 'tab:green'

with open('plot_data/fourier_spectra_empirical.pkl', 'rb') as f:
    spectra = pickle.load(f)
A=20
N=[4,4,4,3]
fourier_vals = {}
d = N*(A-1)
names = ["gb1", "trpb", "tev", "pard3"]
for i, spectrum in enumerate(spectra):
    spectrum = spectrum[1:]
    i_norm = (spectrum - spectrum.min()) / (spectrum.max() - spectrum.min())
    indexes = np.arange(len(spectrum))+1
    d = N[i]*(A-1)
    weighted_avg = np.sum(A * indexes * spectrum) / np.sum(spectrum) / d
    fourier_vals[names[i]] = weighted_avg

# %%
n_boot = 1000
ld_results = {}
eps = 1e-8
example_trajectories = []
npoints = 10
trajectories = {nm:
    np.concatenate([np.array([1],dtype=int),(np.logspace(0,3,npoints)*8).astype('int')]) 
    if nm=="pard3" else np.concatenate([np.array([1],dtype=int),(np.logspace(0,4,npoints)*16).astype('int')] )
                                       for nm in ["gb1", "trpb", "tev", "pard3"]}
empirical_heterogeneity_avg = {
    nm: decays.mean(axis=1)**2
    for nm, decays in empirical_heterogeneity.items()
} # empirical_heterogeneity is dict[name, np.array(num_genotypes x num_reps x num_steps)]
for nm, Gmu in empirical_heterogeneity_avg.items():
    traj_results = []
    example_trajectories.append(Gmu)
    for itraj, traj_number in enumerate(trajectories[nm]):
        boot_vals = []  # 100 bootstrap samples for this traj_number
        for j in range(n_boot):
            idx = np.random.choice(Gmu.shape[0], size=int(traj_number), replace=False)
            num_steps = 25
            mut = 0.1
            fix_amplitude = False
            sample = Gmu[idx]
            if j == 0 and traj_number == 10000:
                example_trajectories.append(sample)
            sample = sample[:,:num_steps].mean(axis=0)
            sample = sample / (np.abs(sample[0]) + eps)
            rho, C, c = get_single_decay_rate_IK_v2(sample,mut=mut,num_steps=num_steps,fix_amplitude=fix_amplitude)
            boot_vals.append(rho/2)
        traj_results.append(np.array(boot_vals))
    ld_results[nm] = traj_results

with open('plot_data/trajectory_subsampling_20rep_IK.pkl', 'wb') as f:
    pickle.dump(ld_results, f)

data_names = ['GB1', 'TrpB', 'TEV', 'ParD3']
colours = [c1,c2,c4,c3]
# trajectories = np.round(np.linspace(10,1000,10))
# trajectories = np.logspace(0,5,6)
plt.figure(figsize=(3.5,3), dpi=300)

for h, (nm, data) in enumerate(ld_results.items()):

    means = []
    errs = []

    for t in range(len(trajectories[nm])):
        vals = ld_results[nm][t]     # (n_boot,)
        means.append(np.mean(vals))
        errs.append(np.std(vals))   # or SEM: np.std(vals) / np.sqrt(len(vals))

    means = np.array(means)
    print(means)
    errs  = np.array(errs)

    plt.plot(
        trajectories[nm],
        means,
        label=data_names[h],
        color = colours[h]
    )

    plt.fill_between(
        trajectories[nm],
        means - errs,
        means + errs,
        alpha=0.25,
        color = colours[h],
        edgecolor=None
    )

    #plt.hlines(
    #    y=fourier_vals[h] xmin=0, xmax=1000, color=colours[h], linestyle='--', alpha=0.4)
    
    plt.hlines(
        y=fourier_vals[nm], xmin=0, xmax=trajectories[nm].max(), color=colours[h], linestyle='dotted',alpha=0.4)

plt.xlabel('Number of trajectories averaged', fontsize=labelsize)
plt.ylabel(r'Decay rate $\rho$', fontsize=labelsize)
plt.title(r'$\rho$ accuracy with increasing samples', fontsize=titlesize)
plt.legend(fontsize = legendsize)
plt.ylim(0,2)
plt.xlim(1,160000)
plt.xscale("log")
plt.tick_params(axis='both', which='major', labelsize=ticksize)
# Out:
# [0.21095144 0.43695951 0.49600712 0.58155392 0.58369763 0.59087254
#  0.58999696 0.59598622 0.59678342 0.59585504 0.59597938]
# [0.72232542 0.91136901 0.76839989 0.61499802 0.60398623 0.59975892
#  0.59881303 0.59838216 0.59838006 0.59809499 0.59813952]
# [0.57718894 0.56268654 0.51032736 0.71917086 0.82925422 1.01842919
#  1.0333802  0.96415912 0.95968398 0.94569065 0.94676988]
# [0.42068187 0.50933623 0.52944653 0.47700754 0.43355152 0.42339027
#  0.41816561 0.4189387  0.41828301 0.41889569 0.41834068]

# %% [markdown]
# Group repeats to check variance

# %%
n_boot = 10
ld_results = {}
eps = 1e-8
example_trajectories = []
npoints = 10
trajectories = {nm:
    np.concatenate([np.array([1],dtype=int),(np.logspace(0,3,npoints)*8).astype('int')]) 
    if nm=="pard3" else np.concatenate([np.array([1],dtype=int),(np.logspace(0,4,npoints)*16).astype('int')] )
                                       for nm in ["gb1", "trpb", "tev", "pard3"]}
num_repeats = 20
ngroup = 10
num_groups = int(num_repeats/ngroup)

empirical_heterogeneity_avg = {
    nm: decays.mean(axis=1)**2
    for nm, decays in empirical_heterogeneity.items()
} # empirical_heterogeneity is dict[name, np.array(num_genotypes x num_reps x num_steps)]
for nm, Gmu in empirical_heterogeneity_avg.items():
    traj_results = []
    example_trajectories.append(Gmu)
    for itraj, traj_number in enumerate(trajectories[nm]):
        boot_vals = []  # 100 bootstrap samples for this traj_number
        for j in range(n_boot):
            idgroup = np.random.choice(num_repeats, size=ngroup, replace=False)
            tmp = empirical_heterogeneity[nm][:, idgroup, :]
            Gmu = tmp.mean(axis=1)**2
            
            idx = np.random.choice(Gmu.shape[0], size=int(traj_number), replace=False)
            num_steps = 25
            mut = 0.1
            fix_amplitude = False
            sample = Gmu[idx]
            if j == 0 and traj_number == 10000:
                example_trajectories.append(sample)
            sample = sample[:,:num_steps].mean(axis=0)
            sample = sample / (np.abs(sample[0]) + eps)
            rho, C, c = get_single_decay_rate_IK_v2(sample,mut=mut,num_steps=num_steps,fix_amplitude=fix_amplitude)
            boot_vals.append(rho/2)
        traj_results.append(np.array(boot_vals))
    ld_results[nm] = traj_results

# with open('plot_data/trajectory_subsampling_20rep_IK.pkl', 'wb') as f:
#     pickle.dump(ld_results, f)

data_names = ['GB1', 'TrpB', 'TEV', 'ParD3']
colours = [c1,c2,c4,c3]
# trajectories = np.round(np.linspace(10,1000,10))
# trajectories = np.logspace(0,5,6)
plt.figure(figsize=(3.5,3), dpi=300)

for h, (nm, data) in enumerate(ld_results.items()):

    means = []
    errs = []

    for t in range(len(trajectories[nm])):
        vals = ld_results[nm][t]     # (n_boot,)
        means.append(np.mean(vals))
        errs.append(np.std(vals))   # or SEM: np.std(vals) / np.sqrt(len(vals))

    means = np.array(means)
    print(means)
    errs  = np.array(errs)

    plt.plot(
        trajectories[nm],
        means,
        label=data_names[h],
        color = colours[h]
    )

    plt.fill_between(
        trajectories[nm],
        means - errs,
        means + errs,
        alpha=0.25,
        color = colours[h],
        edgecolor=None
    )

    #plt.hlines(
    #    y=fourier_vals[h] xmin=0, xmax=1000, color=colours[h], linestyle='--', alpha=0.4)
    
    plt.hlines(
        y=fourier_vals[nm], xmin=0, xmax=trajectories[nm].max(), color=colours[h], linestyle='dotted',alpha=0.4)

plt.xlabel('Number of trajectories averaged', fontsize=labelsize)
plt.ylabel(r'Decay rate $\rho$', fontsize=labelsize)
plt.title(r'$\rho$ accuracy with increasing samples', fontsize=titlesize)
plt.legend(fontsize = legendsize)
plt.ylim(0,2)
plt.xlim(1,160000)
plt.xscale("log")
plt.tick_params(axis='both', which='major', labelsize=ticksize)
# Out:
# [0.40962597 0.286446   0.6418201  0.5787547  0.59453875 0.5949386
#  0.6024625  0.5889999  0.59847803 0.59566854 0.59662973]
# [0.64742145 0.47892001 0.88937042 0.61333994 0.59203417 0.59531919
#  0.59719171 0.59911922 0.60352335 0.5982584  0.59924847]
# [0.44102588 0.78765657 0.65360046 0.78565384 0.87310459 0.92002881
#  0.8861773  1.02595208 0.98091056 0.95049758 0.94759996]
# [0.26483089 0.52870354 0.32369395 0.48037207 0.44224402 0.40008208
#  0.41115101 0.41749363 0.44020794 0.4120276  0.43034541]

# %%
data_names = ['GB1', 'TrpB', 'TEV', 'ParD3']
colours = [c1,c2,c4,c3]
# trajectories = np.round(np.linspace(10,1000,10))
# trajectories = np.logspace(0,5,6)
trajectories = {nm:(np.logspace(0,3,5)*8).astype('int') if nm=="pard3" else (np.logspace(0,4,5)*16).astype('int') for nm in empirical_heterogeneity.keys()}
plt.figure(figsize=(3.5,3), dpi=300)

for h, (nm, data) in enumerate(ld_results.items()):

    means = []
    errs = []

    for t in range(len(trajectories[nm])):
        vals = ld_results[nm][t]     # (n_boot,)
        means.append(np.mean(vals))
        errs.append(np.std(vals))   # or SEM: np.std(vals) / np.sqrt(len(vals))

    means = np.array(means)
    print(means)
    errs  = np.array(errs)

    plt.plot(
        trajectories[nm],
        means,
        label=data_names[h],
        color = colours[h]
    )

    plt.fill_between(
        trajectories[nm],
        means - errs,
        means + errs,
        alpha=0.25,
        color = colours[h],
        edgecolor=None
    )

    #plt.hlines(
    #    y=fourier_vals[h] xmin=0, xmax=1000, color=colours[h], linestyle='--', alpha=0.4)
    
    plt.hlines(
        y=fourier_vals[nm], xmin=0, xmax=trajectories[nm].max(), color=colours[h], linestyle='dotted',alpha=0.4)

plt.xlabel('Number of trajectories averaged', fontsize=labelsize)
plt.ylabel(r'Decay rate $\rho$', fontsize=labelsize)
plt.title(r'$\rho$ accuracy with increasing samples', fontsize=titlesize)
plt.legend(fontsize = legendsize)
plt.ylim(0,1.1)
plt.xscale("log")
plt.tick_params(axis='both', which='major', labelsize=ticksize)
# Out:
# [0.4203356  0.56640475 0.59904453 0.60445671 0.60561149]
# [1.06036094 0.63998817 0.61360212 0.61144683 0.61219727]
# [0.621691   0.91838831 1.11873516 0.97385261 0.95409846]
# [0.5959291  0.50593249 0.48001589 0.47603484 0.47817744]

# %%
all_data = [gb1_decay, trpb_decay, tev_decay]
num_steps = 15
fig, ax = plt.subplots(len(all_data), 1, figsize=(8,5), dpi=300)
for i, t in enumerate(['GB1', 'TrpB', 'TEV']):
    steps = np.arange(0,num_steps)
    data = all_data[i]
    sample = ((data[:,:,:,0:num_steps].reshape(-1,num_steps))**2).mean(axis=0)
    sample = sample / sample[0]
    params = get_single_decay_rate_IK_v2(sample, mut=mut, num_steps=num_steps, fix_amplitude=True)
    y_est = model_function_IK_v2(steps, *params, mut=mut, fix_amplitude=fix_amplitude, F0=sample[0]) 
    ax[i].plot(steps, sample, color='black')
    ax[i].plot(steps, y_est, label=f"rho={params[0]/2:.2f}", color='red', linestyle='--')
    ax[i].set_title(f"{t}")
    ax[i].legend(fontsize=5)
    
plt.tight_layout(pad=2)
plt.show()

# %%
with open('plot_data/trajectory_subsampling_IK.pkl', 'wb') as f:
    pickle.dump(ld_results, f)

# %%
decay_rate_measurements = [(i**2).mean(axis=(0,1,2)) for i in [gb1_decay, trpb_decay, tev_decay, pard3_decay]]
decay_rate_measurements = [i/i[0] for i in decay_rate_measurements]
decay_rate_measurements = [get_single_decay_rate(i)[0]/2 for i in decay_rate_measurements]

# %% [markdown]
# New: locality plot. Look at rho computed from the same starting genotype(s) over several runs.

# %%
with open(os.path.join(slide_data_dir, "decay_curves_gb1_m0.1_all_starts.pkl"), "rb") as f:
    gb1_decay = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_trpb_m0.1_all_starts.pkl"), "rb") as f:
    trpb_decay = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_tev_m0.1_all_starts.pkl"), "rb") as f:
    tev_decay = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_pard3_m0.1_all_starts.pkl"), "rb") as f:
    pard3_decay = pickle.load(f)
    
with open(os.path.join(slide_data_dir, "decay_curves_gb1_m0.1_all_starts_IK_seed10.pkl"), "rb") as f:
    gb1_decay_v2 = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_trpb_m0.1_all_starts_IK_seed10.pkl"), "rb") as f:
    trpb_decay_v2 = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_tev_m0.1_all_starts_IK_seed10.pkl"), "rb") as f:
    tev_decay_v2 = pickle.load(f)
with open(os.path.join(slide_data_dir, "decay_curves_pard3_m0.1_all_starts_IK_seed10.pkl"), "rb") as f:
    pard3_decay_v2 = pickle.load(f)

tot_steps = gb1_decay.shape[-1]
tot_reps = gb1_decay.shape[-2]
# empirical_locality = {
#     nm: decay.reshape(-1,tot_reps,tot_steps) 
#     for nm, decay in zip(["gb1", "trpb", "tev", "pard3"], [gb1_decay, trpb_decay, tev_decay, pard3_decay],strict=True)
# }
# # this gives per ld arrays: num_genotypes x num_reps x num_steps
empirical_locality = {
    nm: np.concatenate(
        [
            decay.reshape(-1, tot_reps, tot_steps),
            decay_v2.reshape(-1, tot_reps, tot_steps)
        ],
        axis=1  # concatenate along reps axis
    )
    for nm, decay, decay_v2 in zip(["gb1", "trpb", "tev", "pard3"], 
                         [gb1_decay, trpb_decay, tev_decay, pard3_decay],
                         [gb1_decay_v2, trpb_decay_v2, tev_decay_v2, pard3_decay_v2],
                         strict=True)
}
# this gives per ld arrays: num_genotypes x 2*num_reps x num_steps
tot_reps *= 2

# %%
n_boot = 100
ld_results = []
eps = 1e-8
example_trajectories = []
trajectories = np.round(np.logspace(0,5,6))

for ii, i in enumerate(empirical_locality):
    
    traj_results = []   # one entry per traj_number
    # i = i[np.abs(i[:,0])>1e-8, :]
    # i = i[np.abs(i[:,0])>np.abs(i[:,-1]), :]
    example_trajectories.append(i)

    for itraj, traj_number in enumerate(trajectories):

        boot_vals = []  # 100 bootstrap samples for this traj_number

        for j in range(n_boot):

            idx = np.random.choice(
                i.shape[0],
                size=int(traj_number),
                replace=True
            )
            
            # Need to limit length - it seems like longer trajectories are too noisy on empirical landscapes
            num_steps = 25
            mut = 0.1
            fix_amplitude = True
            
            sample = i[idx]
            if j == 0 and traj_number == 10000:
                example_trajectories.append(sample)
            sample = sample[:,:num_steps]
            sample = (sample**2).mean(axis=0)
            # print(f"HELLO: {idx}")
            # print(sample)
            sample = sample / (np.abs(sample[0]) + eps)
            rho, C, c = get_single_decay_rate_IK_v2(sample,mut=mut,num_steps=num_steps,fix_amplitude=fix_amplitude)
            # rho, c = get_single_decay_rate(sample,mut=mut,num_steps=num_steps)
            if True: #np.abs(C) > np.abs(0.1*c):
                boot_vals.append(rho/2)

        traj_results.append(np.array(boot_vals))

    ld_results.append(traj_results)
    

all_data = [gb1_decay, trpb_decay, tev_decay]
num_steps = 15
fig, ax = plt.subplots(len(all_data), 1, figsize=(8,5), dpi=300)
for i, t in enumerate(['GB1', 'TrpB', 'TEV', 'ParD3']):
    steps = np.arange(0,num_steps)
    data = all_data[i]
    sample = ((data[:,:,:,0:num_steps].reshape(-1,num_steps))**2).mean(axis=0)
    sample = sample / sample[0]
    params = get_single_decay_rate_IK_v2(sample, mut=mut, num_steps=num_steps, fix_amplitude=True)
    y_est = model_function_IK_v2(steps, *params, mut=mut, fix_amplitude=fix_amplitude, F0=sample[0]) 
    ax[i].plot(steps, sample, color='black')
    ax[i].plot(steps, y_est, label=f"rho={params[0]/2:.2f}", color='red', linestyle='--')
    ax[i].set_title(f"{t}")
    ax[i].legend(fontsize=5)
    
plt.tight_layout(pad=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 21
#      16 boot_vals = []  # 100 bootstrap samples for this traj_number
#      18 for j in range(n_boot):
#      20     idx = np.random.choice(
# ---> 21         i.shape[0],
#      22         size=int(traj_number),
#      23         replace=True
#      24     )
#      26     # Need to limit length - it seems like longer trajectories are too noisy on empirical landscapes
#      27     num_steps = 25
#
# AttributeError: 'str' object has no attribute 'shape'

# %% [markdown]
# Compute rho varying the number of starting genotypes averaged and the number of repetitions

# %%
mut = 0.1
fix_amplitude = True
num_steps = 25
eps = 1e-12
num_starting_genotypes = [10, 100, 1000] # number of genotypes used to obtain Gmu
num_reps = [1, 2, 5, 10, 20] # number of repetitions per starting genotype used to obtain Gmu
sequential_groups = False
LOAD_DATA = True


if LOAD_DATA:
    with open(f"plot_data/rho_locality_numsteps{num_steps}_totreps{tot_reps}_seq{sequential_groups}_IK.pkl", 'rb') as f:
        data_locality = pickle.load(f)
else:
    data_locality = {
        nm: {nsg: {nr: None for nr in num_reps} for nsg in num_starting_genotypes}
        for nm in empirical_locality.keys()
    }

    for i, (nm, decay) in enumerate(empirical_locality.items()):
        tot_genotypes = decay.shape[0]
        decay_squared = decay**2
        decay_squared_norm = decay_squared / (decay_squared[:, :, 0][:, :, None] + eps)
        for nsg in num_starting_genotypes:
            for nr in num_reps:
                print(f"At {nm} with {nsg} starting genotype(s) and {nr} reps")
                num_groups = int(tot_genotypes/nsg)
                if sequential_groups:
                    group_inds = [np.arange(igroup*nsg, (igroup+1)*nsg,dtype=int) for igroup in range(num_groups)]
                else:
                    shuffled = np.random.permutation(tot_genotypes)
                    group_inds = [shuffled[igroup*nsg:(igroup+1)*nsg] for igroup in range(num_groups)]
                num_rep_avg = int(tot_reps/nr) 
                rep_inds = [np.arange(ireps*nr, (ireps+1)*nr,dtype=int) for ireps in range(num_rep_avg)]
                
                this_data = np.array(
                [
                    [ 
                    get_single_decay_rate_IK_v2(
                        decay_squared_norm[g, :, :][:, r, :].reshape(-1, num_steps).mean(axis=0),
                        mut=mut, num_steps=num_steps, fix_amplitude=fix_amplitude
                    )[0]
                    for r in rep_inds
                    ] 
                for g in group_inds
                ]
                )
                data_locality[nm][nsg][nr] = this_data
        
    with open(f"plot_data/rho_locality_numsteps{num_steps}_totreps{tot_reps}_seq{sequential_groups}_IK.pkl", 'wb') as f:
        pickle.dump(data_locality, f)

# %%
# collect labels in consistent order

titlesize = 10
labelsize = 8
ticksize = 6
legendsize = 8

data_mean = {}
data_std = {}
nreps = 5
nstart = 10
for i, nm in enumerate(data_locality.keys()):
    tmp = np.clip(data_locality[nm][nstart][nreps], 0, 20/19)
    data_mean[nm] = tmp.mean(axis=1)
    # data_std[nm] = ((tmp/data_mean[nm][:,None]-1)*100).std(axis=1)
    data_std[nm] = tmp.std(axis=1)
    
labels = list(data_mean.keys())
axis_labels = ['GB1', 'TrpB', 'TEV', 'ParD3']

# compute overall mean + std per dataset
means = [np.mean(data_mean[k]) for k in labels]
stds  = [np.mean(data_std[k])  for k in labels]
# NOTE: using mean of stds (matches your current structure)

import matplotlib.pyplot as plt

plt.figure(figsize=(2.5, 3), dpi=300)

plt.errorbar(
    range(1, len(labels) + 1),
    means,
    yerr=stds,
    fmt='o',
    capsize=3,
    markersize=2
)

plt.xticks(
    range(1, len(labels) + 1),
    axis_labels,
    rotation=30,
    fontsize=ticksize
)
plt.yticks(fontsize=ticksize)
plt.title(f"Replicate heterogeneity", fontsize=titlesize)
plt.ylabel(r'$\rho$ Estimation', fontsize=labelsize)
plt.ylim(-0.1, 1.15)

plt.tight_layout()
plt.savefig('figures/repeat_heterogeneity.pdf', dpi=300)
plt.show()

# %%
# num_starting_genotypes = [10, 100, 1000] # number of genotypes used to obtain Gmu
# num_reps = [1, 2, 5, 10, 20] # number of repetitions per starting genotype used to obtain Gmu
# data_locality[nm][nsg][nr] = this_data
# this_data: num_groups x tot_reps/num_reps
data_mean = {}
data_std = {}
nreps = 5
nstart = 10
for i, nm in enumerate(data_locality.keys()):
    tmp = np.clip(data_locality[nm][nstart][nreps], 0, 20/19)
    data_mean[nm] = tmp.mean(axis=1)
    # data_std[nm] = ((tmp/data_mean[nm][:,None]-1)*100).std(axis=1)
    data_std[nm] = tmp.std(axis=1)
    
    
fig, ax = plt.subplots()
labels = list(data_std.keys())
values = [np.ravel(v) for v in data_std.values()]  # flatten just in case
ax.violinplot(values, showmeans=True, showmedians=True)
ax.set_xticks(np.arange(1, len(labels) + 1))
ax.set_xticklabels(labels)
ax.set_title(f"STDs | nreps={nreps} | nstart={nstart}")

fig, ax = plt.subplots()
labels = list(data_mean.keys())
values = [np.ravel(v) for v in data_mean.values()]  # flatten just in case
ax.violinplot(values, showmeans=True, showmedians=True)
ax.set_xticks(np.arange(1, len(labels) + 1))
ax.set_xticklabels(labels)
ax.set_title("Means")

plt.show()

# %%
fig, ax = plt.subplots()
labels = list(data_std.keys())
values = [np.ravel(v) for v in data_std.values()]  # flatten just in case
ax.violinplot(values, showmeans=True, showmedians=True)
ax.set_xticks(np.arange(1, len(labels) + 1))
ax.set_xticklabels(labels)
ax.set_title("STDs")

fig, ax = plt.subplots()
labels = list(data_mean.keys())
values = [np.ravel(v) for v in data_mean.values()]  # flatten just in case
ax.violinplot(values, showmeans=True, showmedians=True)
ax.set_xticks(np.arange(1, len(labels) + 1))
ax.set_xticklabels(labels)
ax.set_title("Means")

plt.show()

# %%
mut = 0.1
fix_amplitude = True
num_steps = tot_steps
eps = 1e-12
rho_per_genotype = []

for i, decay in enumerate(empirical_locality):
    num_genotypes = decay.shape[0]
    decay_squared = decay**2
    
    rho_per_genotype_ld = np.zeros(shape=(num_genotypes, tot_reps))
    for j in range(num_genotypes):
        decay_squared_norm = decay_squared[j,:,:] / (decay_squared[j, :, 0][:, None] + eps)
        tmp = [
            get_single_decay_rate_IK_v2(decay_squared_norm[r, :], mut=mut,num_steps=num_steps,fix_amplitude=fix_amplitude)[0]
            for r in range(tot_reps)
        ]
        rho_per_genotype_ld[j,:] = tmp
    rho_per_genotype.append(rho_per_genotype_ld)

# %% [markdown]
# ## Optimising directed evolution

# %% [markdown]
# ### Optimal DE strategies from sweep

# %%
## Taking the mean over N.
reshaped_strategies = strategy_data.reshape(100, -1, 300)
N_meaned_strategies = reshaped_strategies[:90].mean(axis=2).reshape(9,10,49).mean(axis=0)
N_meaned_decay_data = normalized_decay_curves.reshape(10,10,250,25).mean(axis=(0,2))

# %%
N_meaned_strategies.shape
# Out:
# (10, 49)

# %%
# Out:
# (100, 7, 7, 300)

# %%
file_path = os.path.join(slide_data_dir, "large_decay_curve_sweep.pkl")
with open(file_path, "rb") as f:
    decay_data = pickle.load(f)
    
file_path = os.path.join(slide_data_dir, "large_strategy_sweep.pkl")
with open(file_path, "rb") as f:
    strategy_data = pickle.load(f)

## Taking the mean over N.
reshaped_decay_curves = decay_data.reshape(100,-1,25)
normalized_decay_curves = reshaped_decay_curves / reshaped_decay_curves[:, :, 0][:, :, np.newaxis]
reshaped_strategies = strategy_data.reshape(100, -1, 300)
N_meaned_strategies = reshaped_strategies[:90].mean(axis=2).reshape(9,10,49).mean(axis=0)
N_meaned_decay_data = normalized_decay_curves.reshape(10,10,250,25).mean(axis=(0,2))



file_path = os.path.join(slide_data_dir, "large_decay_curve_sweep.pkl")
with open(file_path, "rb") as f:
    decay_data = pickle.load(f)

file_path = os.path.join(slide_data_dir, "large_strategy_sweep_50gens.pkl")
with open(file_path, "rb") as f:
    strategy_data_50gens = pickle.load(f)
    
file_path = os.path.join(slide_data_dir, "large_strategy_sweep_25gens.pkl")
with open(file_path, "rb") as f:
    strategy_data_25gens = pickle.load(f)
    
file_path = os.path.join(slide_data_dir, "large_strategy_sweep_60gens.pkl")
with open(file_path, "rb") as f:
    strategy_data_60gens = pickle.load(f)
    
file_path = os.path.join(slide_data_dir, "large_strategy_sweep_100.pkl")
with open(file_path, "rb") as f:
    strategy_data_100gens = pickle.load(f)
    
gens = [25, 50, 60, 100]
strategy_data_allgens = [strategy_data_25gens, strategy_data_50gens, strategy_data_60gens, strategy_data_100gens]
strategy_data_gens = {g:s for g,s in zip(gens, strategy_data_allgens)}

reshaped_strategies_gens = {g:s.reshape(100, -1, 300) for g,s in strategy_data_gens.items()}
N_meaned_strategies_gens = {g:s[:90].mean(axis=2).reshape(9,10,49).mean(axis=0) for g,s in reshaped_strategies_gens.items()}

# %%
decay_rates = []

for i in N_meaned_decay_data:
    decay_rates.append(get_single_decay_rate(i,mut=0.5)[0])
    
decay_rates = np.array(decay_rates)

# %%
## Getting optimal base chances and splits from strategy sweep.

thresholds, base_chances = base_chance_threshold_fixed_prop([0,0.19], 0.2, 7)
splits = [24,20,16,12,8,4,1]

base_chance_array = np.array([base_chances]*7).flatten()
splitting_array = np.array([[24]*7,[20]*7,[16]*7,[12]*7,[8]*7,[4]*7,[1]*7]).flatten()

optimal_splits = []
optimal_base_chances = []

for i in range(10):
    max_val = N_meaned_strategies[i].argmax()
    optimal_splits.append(splitting_array[max_val])
    optimal_base_chances.append(base_chance_array[max_val])

# %%
decay_rates = []

for i in N_meaned_decay_data:
    decay_rates.append(get_single_decay_rate(i,mut=0.5)[0])
    
decay_rates = np.array(decay_rates)


optimal_splits_gens = {}
optimal_base_chances_gens = {}

for g,s in N_meaned_strategies_gens.items():
    optimal_splits_gens[g] = []
    optimal_base_chances_gens[g] = []
    for i in range(10):
        max_val = s[i].argmax()
        optimal_splits_gens[g].append(splitting_array[max_val])
        optimal_base_chances_gens[g].append(base_chance_array[max_val])

# %%
thresholds, base_chances = base_chance_threshold_fixed_prop([0,0.19], 0.2, 7)
splits = [24,20,16,12,8,4,1]

base_chance_array = np.array([base_chances]*7).flatten()
splitting_array = np.array([[24]*7,[20]*7,[16]*7,[12]*7,[8]*7,[4]*7,[1]*7]).flatten()

# %%
# strategy_data_gens[i]: num_K*num_N x num_splits x num_basec x num_reps
# reshaped_strategies_gens[i]: num_K*num_N x num_splits*num_basec x num_reps
titlesize = 10
labelsize = 8
ticksize = 6
legendsize = 8
dpi = 350
plt.rcParams["font.family"] = "DejaVu Sans"
c2 = 'tab:blue'#298c8c'
c1 = 'tab:orange' #800074'
c3 = '#f55f74'
c4 = 'tab:green'

splits_base_chances = [(s,b) for b in base_chances for s in splits]

def NK_grid(N_range, num_samples=10):
    N = jnp.linspace(N_range[0], N_range[1], num=num_samples)
    K = jnp.array([jnp.linspace(1, i, num_samples)
                  for i in N]).reshape(num_samples, num_samples)
    N = jnp.repeat(N, num_samples).reshape(num_samples, num_samples)
    return N, K

N_grid, K_grid = NK_grid([10, 50])
Ns, Ks = N_grid.flatten(), K_grid.flatten()
Ns = jnp.flip(Ns)
Ks = jnp.flip(Ks)
NKs = list(zip(Ns,Ks))

rho_grid = (K_grid)/N_grid
# define bins
bins = np.linspace(start=0.1,stop=1,num=5)
bin_idx = np.digitize(rho_grid, bins,right=True)
bin_idx_flat = bin_idx.flatten()
bin_NKs = jnp.flip(bin_idx_flat)

optimal_splits_gens_v2 = {}
optimal_base_chances_gens_v2 = {}
for g in reshaped_strategies_gens.keys():
    mean_data = reshaped_strategies_gens[g].mean(axis=2) # num_K*num_N x num_splits*num_basec
    this_optim_splits = np.zeros(shape=(len(bins)))
    this_optim_base = np.zeros(shape=(len(bins)))
    for ibin, bin in enumerate(bins):
        inds = bin_NKs == ibin
        mean_data_bin = mean_data[inds, :].mean(axis=0)
        this_optim_splits[ibin], this_optim_base[ibin] = splits_base_chances[mean_data_bin.argmax()]
        if ibin == len(bins)-1:
            zerodata = mean_data_bin
        
    optimal_splits_gens_v2[g] = this_optim_splits
    optimal_base_chances_gens_v2[g] = this_optim_base
    
    fig, ax1 = plt.subplots(figsize=(3.5,3), dpi=300)

    color = c1
    ax1.set_xlabel(r'True $\rho$', fontsize=8)
    ax1.set_ylabel(r'Predicted base chance $b$', color=color, fontsize=8)
    ax1.plot(np.flip(bins), optimal_base_chances_gens_v2[g], color=color, linestyle='--', marker='o', label='Optimal base chance')
    ax1.tick_params(axis='y', labelcolor=color, labelsize=6)
    ax1.tick_params(axis='x', labelsize=6)
    ax1.grid(color='black', linestyle='--', linewidth=0.5, alpha=0.3)

    ax2 = ax1.twinx()  # instantiate a second Axes that shares the same x-axis

    color = c2
    ax2.set_ylabel('Predicted splitting (total 1200)', color=color, fontsize=8)
    ax2.plot(np.flip(bins), optimal_splits_gens_v2[g], color=color, linestyle='--', marker='s', label='Optimal splitting')
    ax2.tick_params(axis='y', labelcolor=color, labelsize=6)

    ax1.set_title(f"Optimal DE strategies (M={g})", fontsize=10)

    # Adjust legend positions
    ax1.legend(fontsize=legendsize-2, loc='upper left', bbox_to_anchor=(0.0, 1.0))
    ax2.legend(fontsize=legendsize-2, loc='upper left', bbox_to_anchor=(0.0, 0.9))  # Move slightly below ax1's legend

    plt.xlim(0.05, 1.05)
    fig.tight_layout()
    fig.tight_layout()
    plt.savefig(f"figures/strategy_prediction_{g}gens_rhobins.pdf", dpi=dpi)

# %%
def NK_grid(N_range, num_samples=10):
    N = jnp.linspace(N_range[0], N_range[1], num=num_samples)
    K = jnp.array([jnp.linspace(1, i, num_samples)
                  for i in N]).reshape(num_samples, num_samples)
    N = jnp.repeat(N, num_samples).reshape(num_samples, num_samples)
    return N, K

N_grid, K_grid = NK_grid([10, 50])

Ns, Ks = N_grid.flatten(), K_grid.flatten()
Ns = jnp.flip(Ns)
Ks = jnp.flip(Ks)
NKs = list(zip(Ns,Ks))

NKs = np.array(NKs)
k_over_ns = (NKs[:,1]+1)/NKs[:,0]

## Predictions from 10 isolated runs

predicted_base_chances_gens = {}
predicted_splittings_gens = {}
actual_k_over_ns_gens = {}

for g in reshaped_strategies_gens.keys():
    predicted_base_chances_gens[g] = []
    predicted_splittings_gens[g] = []
    actual_k_over_ns_gens[g] = []

    for landscape in range(normalized_decay_curves.shape[0]):

        landscape_outcomes = []

        # For each ld, take mean across all reps and reshape into strategy space.
        landscape_strategy_outcomes = reshaped_strategies_gens[g][landscape,:,:].mean(axis=1).reshape(7,7)

        for run in range(100):

            ### Estimate decay rate (k/n).
            run_data = normalized_decay_curves[landscape, run,:]
            run_decay_rate = get_single_decay_rate(run_data,mut=0.5)[0]
            actual_k_over_ns_gens[g].append(k_over_ns[landscape])

            ### Collect predicted vs actual 
            predicted_base_chance = optimal_base_chances_gens_v2[g][np.digitize(run_decay_rate, bins, right=True)]
            predicted_splitting = optimal_splits_gens_v2[g][np.digitize(run_decay_rate, bins, right=True)]
            predicted_base_chances_gens[g].append(predicted_base_chance)
            predicted_splittings_gens[g].append(predicted_splitting)
        
        
rounded_actual_gens = {g:np.round(s, 1) for g,s in actual_k_over_ns_gens.items()}

unique_x_gens = {g:np.unique(s) for g,s in rounded_actual_gens.items()}

bc_means_gens = {}
bc_stds_gens = {}
sp_means_gens = {}
sp_stds_gens = {}

for g in predicted_base_chances_gens.keys():
    bc_means_gens[g] = []
    bc_stds_gens[g] = []
    sp_means_gens[g] = []
    sp_stds_gens[g] = []

    for x in unique_x_gens[g]:
        # Select points corresponding to the current x value
        bc_values = np.array(predicted_base_chances_gens_v2[g])[rounded_actual_gens[g] == x]
        bc_means_gens[g].append(np.mean(bc_values))
        bc_stds_gens[g].append(np.std(bc_values))
        
        # Select points corresponding to the current x value
        sp_values = np.array(predicted_splittings_gens_v2[g])[rounded_actual_gens[g] == x]
        sp_means_gens[g].append(np.mean(sp_values))
        sp_stds_gens[g].append(np.std(sp_values))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 44
#      41 actual_k_over_ns_gens[g].append(k_over_ns[landscape])
#      43 ### Collect predicted vs actual
# ---> 44 predicted_base_chance = optimal_base_chances_gens_v2[g][np.digitize(run_decay_rate, bins, right=True)]
#      45 predicted_splitting = optimal_splits_gens_v2[g][np.digitize(run_decay_rate, bins, right=True)]
#      46 predicted_base_chances_gens[g].append(predicted_base_chance)
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
def NK_grid(N_range, num_samples=10):
    N = jnp.linspace(N_range[0], N_range[1], num=num_samples)
    K = jnp.array([jnp.linspace(1, i, num_samples)
                  for i in N]).reshape(num_samples, num_samples)
    N = jnp.repeat(N, num_samples).reshape(num_samples, num_samples)
    return N, K

N_grid, K_grid = NK_grid([10, 50])

Ns, Ks = N_grid.flatten(), K_grid.flatten()
Ns = jnp.flip(Ns)
Ks = jnp.flip(Ks)
NKs = list(zip(Ns,Ks))

NKs = np.array(NKs)
k_over_ns = (NKs[:,1]+1)/NKs[:,0]

## Predictions from 10 isolated runs

predicted_base_chances_gens = {}
predicted_splittings_gens = {}
actual_k_over_ns_gens = {}

for g in reshaped_strategies_gens.keys():
    predicted_base_chances_gens[g] = []
    predicted_splittings_gens[g] = []
    actual_k_over_ns_gens[g] = []

    for landscape in range(normalized_decay_curves.shape[0]):

        landscape_outcomes = []

        # For each ld, take mean across all reps and reshape into strategy space.
        landscape_strategy_outcomes = reshaped_strategies_gens[g][landscape,:,:].mean(axis=1).reshape(7,7)

        for run in range(100):

            ### Estimate decay rate (k/n).
            run_data = normalized_decay_curves[landscape, run,:]
            run_decay_rate = get_single_decay_rate(run_data,mut=0.5)[0]
            actual_k_over_ns_gens[g].append(k_over_ns[landscape])

            ### Collect predicted vs actual 
            predicted_base_chance = optimal_base_chances_gens[g][np.argmin(np.abs(decay_rates - run_decay_rate))]
            predicted_splitting = optimal_splits_gens[g][np.argmin(np.abs(decay_rates - run_decay_rate))]
            predicted_base_chances_gens[g].append(predicted_base_chance)
            predicted_splittings_gens[g].append(predicted_splitting)
        
        
rounded_actual_gens = {g:np.round(s, 1) for g,s in actual_k_over_ns_gens.items()}

unique_x_gens = {g:np.unique(s) for g,s in rounded_actual_gens.items()}

bc_means_gens = {}
bc_stds_gens = {}
sp_means_gens = {}
sp_stds_gens = {}

for g in predicted_base_chances_gens.keys():
    bc_means_gens[g] = []
    bc_stds_gens[g] = []
    sp_means_gens[g] = []
    sp_stds_gens[g] = []

    for x in unique_x_gens[g]:
        # Select points corresponding to the current x value
        bc_values = np.array(predicted_base_chances_gens[g])[rounded_actual_gens[g] == x]
        bc_means_gens[g].append(np.mean(bc_values))
        bc_stds_gens[g].append(np.std(bc_values))
        
        # Select points corresponding to the current x value
        sp_values = np.array(predicted_splittings_gens[g])[rounded_actual_gens[g] == x]
        sp_means_gens[g].append(np.mean(sp_values))
        sp_stds_gens[g].append(np.std(sp_values))

# %%
decay_rates
# Out:
# array([0.9660258 , 0.89393492, 0.8024007 , 0.68906048, 0.59124377,
#        0.47743633, 0.3916307 , 0.28275242, 0.20408572, 0.13995675])

# %%
## Plot colours

c2 = 'tab:blue'#298c8c'
c1 = 'tab:orange' #800074'
c3 = '#f55f74'
c4 = 'tab:green'

## Fontsizes

titlesize = 10
labelsize = 8
ticksize = 6
legendsize = 8
dpi = 350
plt.rcParams["font.family"] = "DejaVu Sans"

for g in optimal_splits_gens.keys():
    optimal_splits, optimal_base_chances = (optimal_splits_gens[g], optimal_base_chances_gens[g])
    
    fig, ax1 = plt.subplots(figsize=(3.5,3), dpi=300)

    k_over_ns = np.unique(np.round(actual_k_over_ns_gens[g],1))

    color = c1
    ax1.set_xlabel(r'True $\rho$', fontsize=8)
    ax1.set_ylabel(r'Predicted base chance $b$', color=color, fontsize=8)
    ax1.errorbar(k_over_ns, bc_means_gens[g], yerr=bc_stds_gens[g], fmt='o', capsize=5, color=c1)
    ax1.plot(decay_rates, optimal_base_chances_gens[g], color=color, linestyle='--', alpha=0.6, label='Optimal base chance')
    ax1.tick_params(axis='y', labelcolor=color, labelsize=6)
    ax1.tick_params(axis='x', labelsize=6)
    ax1.grid(color='black', linestyle='--', linewidth=0.5, alpha=0.3)

    ax2 = ax1.twinx()  # instantiate a second Axes that shares the same x-axis

    color = c2
    ax2.set_ylabel('Predicted splitting (total 1200)', color=color, fontsize=8) 
    ax2.errorbar(k_over_ns, sp_means_gens[g], yerr=sp_stds_gens[g], fmt='o', capsize=5, color=c2)
    ax2.plot(decay_rates, optimal_splits_gens[g], color=color, linestyle='--', alpha=0.6, label='Optimal splitting')
    ax2.tick_params(axis='y', labelcolor=color, labelsize=6)

    ax1.set_title(f"Optimal DE strategies (M={g})", fontsize=10)

    # Adjust legend positions
    ax1.legend(fontsize=legendsize-2, loc='upper left', bbox_to_anchor=(0.0, 1.0))
    ax2.legend(fontsize=legendsize-2, loc='upper left', bbox_to_anchor=(0.0, 0.9))  # Move slightly below ax1's legend

    plt.xlim(0.05, 1.05)
    fig.tight_layout()
    plt.savefig(f"figures/strategy_prediction_{g}gens.pdf", dpi=dpi)

# %%
with open('plot_data/optimal_DE_strategies_gens_IK.pkl', 'wb') as f:
    pickle.dump((decay_rates, optimal_splits_gens, optimal_base_chances_gens), f)

# %% [markdown]
# ### Number of generations impact on strategy choice

# %%
file_path = os.path.join(slide_data_dir, "N4A20_strategy_sweep_100_gens.pkl")
with open(file_path, "rb") as f:
    strategy_data_100_gens = pickle.load(f)

file_path = os.path.join(slide_data_dir, "N4A20_strategy_sweep_75_gens.pkl")
with open(file_path, "rb") as f:
    strategy_data_75_gens = pickle.load(f)

file_path = os.path.join(slide_data_dir, "N4A20_strategy_sweep_50_gens.pkl")
with open(file_path, "rb") as f:
    strategy_data_50_gens = pickle.load(f)

file_path = os.path.join(slide_data_dir, "N4A20_strategy_sweep_25_gens.pkl")
with open(file_path, "rb") as f:
    strategy_data_25_gens = pickle.load(f)

file_path = os.path.join(slide_data_dir, "N4A20_strategy_sweep_5_gens.pkl")
with open(file_path, "rb") as f:
    strategy_data_5_gens = pickle.load(f)

# %%
all_strategy_data = np.array([strategy_data_5_gens.mean(axis=0),
                              strategy_data_25_gens.mean(axis=0),
                              strategy_data_50_gens.mean(axis=0),
                              strategy_data_75_gens.mean(axis=0),
                              strategy_data_100_gens.mean(axis=0)])

# %%
import matplotlib.pyplot as plt
import numpy as np

strategy_data = all_strategy_data

fig, axes = plt.subplots(5, 3, figsize=(12, 10))

x_labels = [5, 25, 50, 75, 100]
line_labels = ['Line 1', 'Line 2', 'Line 3']

splits = [24, 20, 16, 12, 8, 4, 1]
thresholds, base_chances = base_chance_threshold_fixed_prop([0,0.19], 0.2, 7)

max_vals = np.zeros((5,3))
max_vals_bc = np.zeros((5,3))

for i in range(5):
    for j in range(3):
        ax = axes[i, j]

        data = strategy_data[i, j]

        im = ax.imshow(
            data,
            origin='lower',
            cmap='viridis',
            aspect='auto'
        )

        # ---- FIND AND PLOT MAX POINT ----
        max_idx = np.unravel_index(np.argmax(data), data.shape)
        y_max, x_max = max_idx  # row, col

        max_vals[i,j] = y_max
        max_vals_bc[i,j] = x_max

        ax.scatter(
            x_max, y_max,
            color='red',
            s=25,
            marker='o',
            edgecolors='white',
            linewidth=0.5,
            zorder=3
        )
        # ---------------------------------

        # Ticks
        ax.set_xticks(range(7))
        ax.set_yticks(range(7))
        ax.set_xticklabels([f"{bc:.2f}" for bc in base_chances])
        ax.set_yticklabels(splits)
        ax.set_box_aspect(1)
        
        # Labels
        if i == 4:
            ax.set_xlabel('Base chance')
        if j == 0:
            ax.set_ylabel('Population split')

        # Column titles
        if i == 0:
            ax.set_title(line_labels[j])

# Shared colorbar
cbar = fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.6)
cbar.set_label('Strategy value')

plt.suptitle('Strategy Data (5×3 grid)', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])

plt.show()
# Out:
# /tmp/ipykernel_2737550/4225310407.py:70: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.96])

# %%
splits = [1,4,8,12,16,20,24]
splits_arr = np.array(splits)
max_vals_splits = splits_arr[max_vals.astype(int)]

# %%
bc_arr = np.array(base_chances)
max_vals_bc_array = bc_arr[max_vals_bc.astype(int)]

# %%
plt.figure(figsize=(6,4), dpi=200)
labels = ['K=0', 'K=1', 'K=2']
gens = [5,25,50,75,100]
for i in range(3):
    plt.plot(gens, max_vals_splits[:,i], label=labels[i])
plt.legend()
plt.xlabel('Generations')
plt.ylabel('Optimal population split')
plt.title('Optimal Population Split Over DE Generations')
plt.axvline(25, c='gray', linestyle='--', alpha=0.4)

# %%
plt.figure(figsize=(6,4), dpi=200)
labels = ['K=0', 'K=1', 'K=2']
for i in range(3):
    plt.plot(max_vals_bc_array[:,i], label=labels[i])
plt.legend()
plt.xlabel('Generations')
plt.ylabel('Optimal population base chance')
plt.title('Optimal Population Base Chance Over DE Generations')
plt.ylim(-0.01,base_chances.max())
# Out:
# (-0.01, 0.1899999976158142)

# %% [markdown]
# ### Accuracy of strategy prediction

# %%
NKs = np.array(NKs)
k_over_ns = (NKs[:,1]+1)/NKs[:,0]

# %%
## Predictions from 10 isolated runs

predicted_base_chances = []
predicted_splittings = []
actual_k_over_ns = []

for landscape in range(normalized_decay_curves.shape[0]):

    landscape_outcomes = []

    # For each ld, take mean across all reps and reshape into strategy space.
    landscape_strategy_outcomes = reshaped_strategies[landscape,:,:].mean(axis=1).reshape(7,7)

    for run in range(100):

        ### Estimate decay rate (k/n).
        run_data = normalized_decay_curves[landscape, run,:]
        run_decay_rate = get_single_decay_rate(run_data,mut=0.5)[0]
        actual_k_over_ns.append(k_over_ns[landscape])

        ### Collect predicted vs actual 
        predicted_base_chance = optimal_base_chances[np.argmin(np.abs(decay_rates - run_decay_rate))]
        predicted_splitting = optimal_splits[np.argmin(np.abs(decay_rates - run_decay_rate))]
        predicted_base_chances.append(predicted_base_chance)
        predicted_splittings.append(predicted_splitting)
        
        
rounded_actual = np.round(actual_k_over_ns, 1)

unique_x = np.unique(rounded_actual)

bc_means = []
bc_stds = []

for x in unique_x:
    # Select points corresponding to the current x value
    bc_values = np.array(predicted_base_chances)[rounded_actual == x]
    bc_means.append(np.mean(bc_values))
    bc_stds.append(np.std(bc_values))

sp_means = []
sp_stds = []

for x in unique_x:
    # Select points corresponding to the current x value
    sp_values = np.array(predicted_splittings)[rounded_actual == x]
    sp_means.append(np.mean(sp_values))
    sp_stds.append(np.std(sp_values))

# %%
rounded_actual = np.round(actual_k_over_ns, 1)

unique_x = np.unique(rounded_actual)

bc_means = []
bc_stds = []

for x in unique_x:
    # Select points corresponding to the current x value
    bc_values = np.array(predicted_base_chances)[rounded_actual == x]
    bc_means.append(np.mean(bc_values))
    bc_stds.append(np.std(bc_values))

sp_means = []
sp_stds = []

for x in unique_x:
    # Select points corresponding to the current x value
    sp_values = np.array(predicted_splittings)[rounded_actual == x]
    sp_means.append(np.mean(sp_values))
    sp_stds.append(np.std(sp_values))

# %%
with open('plot_data/strategy_prediction_accuracy.pkl', 'wb') as f:
    # pickle.dump((actual_k_over_ns, bc_means, bc_stds, sp_means, sp_stds), f)

# %% [markdown]
# ### NK directed evo

# %%
## Get predicted base chance and splitting values from N = 45, K = [1,25,45]

NK_samples = [(45,1), (45,25),(45,1), (45,25),]
indexes_of_interest = [1900,1400,1000]
NK_bc_predictions = [0.0,0.0]
NK_th_predictions = [0.8,0.8]
NK_sp_predictions = [1,1]

for i in indexes_of_interest:

    mean_bc_pred = np.array(predicted_base_chances[i:i+100]).mean()
    mean_sp_pred = np.array(predicted_splittings[i:i+100]).mean()

    # Get the closest to the standard values.
    bc = base_chances[np.argmin(np.abs(base_chances - mean_bc_pred))]
    th = thresholds[np.argmin(np.abs(base_chances - mean_bc_pred))]
    sp = splits[np.argmin(np.abs(splits - mean_sp_pred))]

    NK_bc_predictions.append(bc)
    NK_th_predictions.append(th)
    NK_sp_predictions.append(sp)

# %%
# This version of the DE function is modified to allow splits (by ensuring each split begins from the same starting location).

def directedEvolution(s_rng, 
                      rng_rep,
                      selection_strategy, 
                      selection_params, 
                      empirical = False, 
                      N = None, 
                      K = None, 
                      landscape = None, 
                      popsize=100, 
                      mut_chance=0.01, 
                      num_steps=50, 
                      num_reps=10, 
                      define_i_pop=None, 
                      average=True):
    
 
    # Get initial population.
    if define_i_pop == None:
        i_pop = jnp.array([jr.randint(rng_rep, (N,), 0, 2)]*popsize)
    else:
        i_pop = define_i_pop
 
    # Function for evaluating fitness.
    if empirical:
        fitness_function = build_empirical_landscape_function(landscape)
        mutation_function = build_mutation_function(mut_chance, 20)
    else:
        fitness_function = build_NK_landscape_function(rng_rep, N, K)
        mutation_function = build_mutation_function(mut_chance, 2)
 
    # Define selection function.
    selection_function = build_selection_function(
        selection_strategy, selection_params)
 
    # Bringing it all together.
    vmapped_run = jax.jit(jax.vmap(lambda r: run_directed_evolution(
        r, i_pop, selection_function, mutation_function, fitness_function=fitness_function, num_steps=num_steps)[1]))
    
    # The array of seeds we will take as input.
    rng_seeds = jr.split(s_rng, num_reps)
    results = vmapped_run(rng_seeds)
 
    return results

# %%
three_NK_results = []

for i in range(4):

    N,K = NK_samples[i]
    bc = NK_bc_predictions[i]
    s = NK_sp_predictions[i]
    th = NK_th_predictions[i]
    p=1200
    m=0.1
    params = {'base chance':bc, 'threshold': th}

    print('N: ', N, ', K: ', K, ', bc: ', bc, ', sp: ', s)

    rep_rngs = jr.split(jr.PRNGKey(42),100)

    def single_rep(rng_rep):

        split_rngs = jr.split(rng_rep, s)

        def single_s(s_rng):
            params = {'threshold': th, 'base_chance' : bc}
            run = directedEvolution(s_rng,
                                    rng_rep,
                                    N = int(N),
                                    K=int(K),
                                    selection_strategy=slct.base_chance_threshold_select,
                                    selection_params = params,
                                    popsize=int(p/s),
                                    mut_chance=m/int(N),
                                    num_steps=50,
                                    num_reps=1,
                                    average=True)

            #split_results.append(run['fitness'].max(axis=2).mean(axis=0)[-1])
            ##return run['fitness'][:,:,-1].max(axis=1).mean()
            return run['fitness'][:,:,:].mean(axis=0)

        split_results = jax.vmap(single_s)(split_rngs)

        return jnp.array(split_results)

    repeat_results = jax.vmap(single_rep)(rep_rngs)

    three_NK_results.append(repeat_results)
# Out:
# N:  45 , K:  1 , bc:  0.0 , sp:  1
# N:  45 , K:  25 , bc:  0.0 , sp:  1
# N:  45 , K:  1 , bc:  0.0 , sp:  4
# N:  45 , K:  25 , bc:  0.0 , sp:  24

# %%
## Extracting winning splits in post
new_output = []
for i in three_NK_results:
    winning_splits_only = []
    for ii in range(i.shape[0]): # for each rep
        rep = i[ii]
        final_max = rep[:,-1,:].max(axis=1)
        winning_split = np.argmax(final_max)
        winning_splits_only.append(rep[winning_split])
    new_output.append(np.array(winning_splits_only).mean(axis=(0,2)))

# %%
with open('plot_data/NK_DE.pkl', 'wb') as f:
    # pickle.dump(new_output, f)

# %% [markdown]
# ### Strategy spaces

# %%
reshaped_strategies = strategy_data.reshape(100, -1, 300)
with open('plot_data/NK_strategy_spaces.pkl', 'wb') as f:
    # pickle.dump((reshaped_strategies[19,:,:],reshaped_strategies[14,:,:]), f)

# %% [markdown]
# # Directed evolution on real landscapes

# %%
with open(os.path.join(slide_data_dir, "N4A20_strategy_sweep.pkl"), "rb") as f:
    strategy_data = pickle.load(f)

with open(os.path.join(slide_data_dir, "N4A20_decay_curves.pkl"), "rb") as f:
    decay_data = pickle.load(f)

# %%
decay_rates = []
decay_means = []
for n, i in enumerate(decay_data[1:]):
    decay_mean = (i**2).mean(axis=(0,1,2))
    decay_mean = decay_mean / decay_mean[0]
    decay_means.append(decay_mean)
    decay_rate = get_single_decay_rate(decay_mean,mut=0.1)
    decay_rates.append(decay_rate[0]/2)

optimal_pos = []
for n, i in enumerate(np.array(strategy_data).mean(axis=0)):

    # Find the index of the maximum value
    max_pos = np.unravel_index(np.argmax(i.T), i.shape)
    optimal_pos.append(max_pos)

# %%
## Saving data
with open('plot_data/empirical_lookup.pkl', 'wb') as f:
    # pickle.dump((decay_rates, decay_means, optimal_pos, np.array(strategy_data).mean(axis=0)), f)

# %%
thresholds, base_chances = base_chance_threshold_fixed_prop([0,0.19], 0.2, 7)
splits = [24,20,16,12,8,4,1]

optimal_base_chances = [base_chances[i[1]] for i in optimal_pos]
optimal_splits = [splits[i[0]] for i in optimal_pos]
# Out:
# E0216 09:55:35.266613  144054 cuda_dnn.cc:535] Could not create cudnn handle: <unknown cudnn status: 4004>
# E0216 09:55:35.266638  144054 cuda_dnn.cc:539] Memory usage: 11010048 bytes free, 12619939840 bytes total.
# E0216 09:55:35.267474  144054 cuda_dnn.cc:535] Could not create cudnn handle: <unknown cudnn status: 4004>
# E0216 09:55:35.267488  144054 cuda_dnn.cc:539] Memory usage: 11010048 bytes free, 12619939840 bytes total.
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 thresholds, base_chances = base_chance_threshold_fixed_prop([0,0.19], 0.2, 7)
#       2 splits = [24,20,16,12,8,4,1]
#       4 optimal_base_chances = [base_chances[i[1]] for i in optimal_pos]
#
# File ~/SLIDE/direvo_functions.py:230, in base_chance_threshold_fixed_prop(base_chance_range, proportion, num_samples)
#     225     return (1-proportion)/(1-base_chance)
# ...

# %%
# Loading all files

with open(os.path.join(slide_data_dir, "decay_curves_gb1_m0.1_multistart_10000_uniform.pkl"), "rb") as f:
    GB1_decay_multi = pickle.load(f)

with open(os.path.join(slide_data_dir, "decay_curves_trpb_m0.1_multistart_10000_uniform.pkl"), "rb") as f:
    TrpB_decay_multi = pickle.load(f)

with open(os.path.join(slide_data_dir, "decay_curves_tev_m0.1_multistart_10000_uniform.pkl"), "rb") as f:
    TEV_decay_multi = pickle.load(f)

with open(os.path.join(slide_data_dir, "decay_curves_pard3_m0.1_multistart_10000_uniform.pkl"), "rb") as f:
    ParD3_decay_multi = pickle.load(f)


with open(os.path.join(slide_data_dir, "strategy_sweep_GB1_multistart_100_uniform_m0.025.pkl"), "rb") as f:
    GB1_sweep_multi = pickle.load(f)

with open(os.path.join(slide_data_dir, "strategy_sweep_TrpB_multistart_100_uniform_m0.025.pkl"), "rb") as f:
    TrpB_sweep_multi = pickle.load(f)

with open(os.path.join(slide_data_dir, "strategy_sweep_TEV_multistart_100_uniform_m0.025.pkl"), "rb") as f:
    TEV_sweep_multi = pickle.load(f)

with open(os.path.join(slide_data_dir, "strategy_sweep_E3_multistart_100_uniform_m0.025.pkl"), "rb") as f:
    ParD3_sweep_multi = pickle.load(f)

# %%
decay_rates
# Out:
# [np.float64(0.5213770732525258),
#  np.float64(0.8060530092414313),
#  np.float64(0.9999999999962792)]

# %%
def empirical_strategy_selection(decay, sweep, decay_rates, optimal_base_chances, optimal_splits, N=4):

    def strategy_from_decay(decay_rate, standard_decay_rates = decay_rates, optimal_base_chances = optimal_base_chances, optimal_splits = optimal_splits):
        
        optimum_index = np.argmin(np.abs(standard_decay_rates - decay_rate))
        
        return optimal_base_chances[optimum_index], optimal_splits[optimum_index]

    # Compute data needed for all subplots
    #decay_mean = decay.mean(axis=(0,1))
    decay_mean = (decay**2).mean(axis=(0,1,2))
    decay_std = (decay**2).std(axis=(0,1,2))
    decay_mean = decay_mean / decay_mean[0]
    decay_rate = get_single_decay_rate(decay_mean,mut=0.1)
    x_vals = np.linspace(0, 24, 25)
    strategy = strategy_from_decay(decay_rate[0]/2)

    print(decay_rate[0]/2)

    def normalise_decay(y_vals, constant):
        out = y_vals - constant
        return out/out[0]

    scatter = normalise_decay(decay_mean, decay_rate[1])
    line = normalise_decay(model_function(x_vals, *decay_rate), decay_rate[1])

    if N==3:
        scipy_freq_matrix = np.zeros((5, 5), dtype=int)
        _, base_chances = base_chance_threshold_fixed_prop([0,0.19], 0.2, 5)
        splits = [20,15,10,5,1]
    else:
        scipy_freq_matrix = np.zeros((7, 7), dtype=int)
        _, base_chances = base_chance_threshold_fixed_prop([0,0.19], 0.2, 7)
        splits = [24,20,16,12,8,4,1]

    j = np.where(np.array(base_chances) == strategy[0])[0]
    i = np.where(np.array(splits) == strategy[1])[0]
    scipy_freq_matrix[i,j] = 1

    print(strategy)

    return(x_vals, decay_mean, decay_rate, sweep, scipy_freq_matrix, strategy, scatter, line)

def uniform_start_locs(ld, num=10000):
    flat_ld = ld.flatten()
    flat_indexes = np.round(np.linspace(0, flat_ld.shape[0]-1, num)).astype(int)
    indexes = np.array([np.unravel_index(i, ld.shape) for i in flat_indexes])
    return indexes

def test_strategy_empirical(ld, bcs, sps, ths, starts):

    ld = jnp.array(ld)

    start_results = []

    for start in tqdm.tqdm(starts):

        results = []

        for i in range(2):

            bc = bcs[i]
            s = sps[i]
            th = ths[i]
            if len(ld.shape) == 4:
                p=1200
            if len(ld.shape) == 3:
                p=60
            m=0.01

            rep_rngs = jr.split(jr.PRNGKey(42),100)

            def single_rep(rng_rep):

                split_rngs = jr.split(rng_rep, s)

                def single_s(s_rng):
                    params = {'threshold': th, 'base_chance' : bc}
                    
                    run = directedEvolution(s_rng,
                                            rng_rep,
                                            selection_strategy=slct.base_chance_threshold_select,
                                            selection_params = params,
                                            popsize=int(p/s),
                                            mut_chance=m,
                                            num_steps=150,
                                            num_reps=1,
                                            define_i_pop=jnp.array([start]*int(p/s)),
                                            empirical=True,
                                            landscape=ld,
                                            average=True)

                    return run['fitness'][:,:,:].mean(axis=0)

                split_results = jax.vmap(single_s)(split_rngs)

                return jnp.array(split_results)

            repeat_results = jax.vmap(single_rep)(rep_rngs)

            results.append(repeat_results)

        ## Extracting winning splits in post
        run = []
        for i in results:
            winning_splits_only = []
            for ii in range(i.shape[0]): # for each rep
                rep = i[ii]
                final_max = rep[:,-1,:].max(axis=1)
                winning_split = np.argmax(final_max)
                winning_splits_only.append(rep[winning_split])
            run.append(np.array(winning_splits_only))#.mean(axis=(0,2)))

        start_results.append(run)

    return start_results

# %%
## GB1

x_vals, decay_mean, decay_rate, sweep, scipy_freq_matrix, strategy, scatter, line = empirical_strategy_selection(GB1_decay_multi, GB1_sweep_multi, decay_rates, optimal_base_chances, optimal_splits)

run = test_strategy_empirical(GB1, [0.0,strategy[0]], 
                        [1,strategy[1]], 
                        [0.8,thresholds[np.array(base_chances) == strategy[0]]],
                        starts=uniform_start_locs(ld=GB1, num=10))

## Saving data
with open('plot_data/GB1_strategy_selection.pkl', 'wb') as f:
    # pickle.dump((x_vals, decay_mean, decay_rate, sweep, scipy_freq_matrix, run, scatter, line, GB1_decay_multi), f)
# Out:
# 0.5933880070003575
# (Array(0., dtype=float32), 16)
# ...
# 100%|██████████| 10/10 [00:29<00:00,  2.98s/it]

# %%
## TrpB

x_vals, decay_mean, decay_rate, sweep, scipy_freq_matrix, strategy, scatter, line = empirical_strategy_selection(TrpB_decay_multi, TrpB_sweep_multi, decay_rates, optimal_base_chances, optimal_splits)

run = test_strategy_empirical(TrpB, [0.0,strategy[0]], 
                        [1,strategy[1]], 
                        [0.8,thresholds[np.array(base_chances) == strategy[0]]],
                        starts=uniform_start_locs(ld=TrpB, num=10))

## Saving data
with open('plot_data/TrpB_strategy_selection.pkl', 'wb') as f:
    # pickle.dump((x_vals, decay_mean, decay_rate, sweep, scipy_freq_matrix, run, scatter, line, TrpB_decay_multi), f)
# Out:
# 0.6130334160370388
# (Array(0., dtype=float32), 16)
# 100%|██████████| 10/10 [00:29<00:00,  2.94s/it]

# %%
## TEV

x_vals, decay_mean, decay_rate, sweep, scipy_freq_matrix, strategy, scatter, line = empirical_strategy_selection(TEV_decay_multi, TEV_sweep_multi, decay_rates, optimal_base_chances, optimal_splits)

run = test_strategy_empirical(TEV, [0.0,strategy[0]], 
                        [1,strategy[1]], 
                        [0.8,thresholds[np.array(base_chances) == strategy[0]]],
                        starts=uniform_start_locs(ld=TEV, num=10))

## Saving data
with open('plot_data/TEV_strategy_selection.pkl', 'wb') as f:
    # pickle.dump((x_vals, decay_mean, decay_rate, sweep, scipy_freq_matrix, run, scatter, line, TEV_decay_multi), f)
# Out:
# 0.8268438024334324
# (Array(0., dtype=float32), 24)
# 100%|██████████| 10/10 [00:30<00:00,  3.01s/it]

# %%
import os
with open(os.path.join(slide_data_dir, "N3A20_strategy_sweep.pkl"), "rb") as f:
    strategy_data = pickle.load(f)

with open(os.path.join(slide_data_dir, "N3A20_decay_curves.pkl"), "rb") as f:
    decay_data = pickle.load(f)

# %%
decay_rates = []
decay_means = []
for n, i in enumerate(decay_data[1:]):
    decay_mean = (i**2).mean(axis=(0,1,2))
    decay_mean = decay_mean / decay_mean[0]
    decay_means.append(decay_mean)
    decay_rate = get_single_decay_rate(decay_mean,mut=0.1)
    decay_rates.append(decay_rate[0]/2)

optimal_pos = []
for n, i in enumerate(np.array(strategy_data).mean(axis=0)):

    # Find the index of the maximum value
    max_pos = np.unravel_index(np.argmax(i.T), i.shape)
    optimal_pos.append(max_pos)

# %%
thresholds, base_chances = base_chance_threshold_fixed_prop([0,0.19], 0.2, 5)

# %%
## ParD3

thresholds, base_chances = base_chance_threshold_fixed_prop([0,0.19], 0.2, 5)
splits = [20,15,10,5,1]

optimal_base_chances = [base_chances[i[1]] for i in optimal_pos]
optimal_splits = [splits[i[0]] for i in optimal_pos]

x_vals, decay_mean, decay_rate, sweep, scipy_freq_matrix, strategy, scatter, line = empirical_strategy_selection(ParD3_decay_multi, ParD3_sweep_multi, decay_rates, optimal_base_chances, optimal_splits,N=3)

run = test_strategy_empirical(ParD3, [0.0,strategy[0]], 
                        [1,strategy[1]], 
                        [0.8,thresholds[np.array(base_chances) == strategy[0]]],
                        starts=uniform_start_locs(ld=ParD3, num=10))

## Saving data
with open('plot_data/ParD3_strategy_selection.pkl', 'wb') as f:
    # pickle.dump((x_vals, decay_mean, decay_rate, sweep, scipy_freq_matrix, run, scatter, line, ParD3_decay_multi), f)
# Out:
# 0.4416724770585169
# (Array(0., dtype=float32), 1)
# 100%|██████████| 10/10 [00:25<00:00,  2.58s/it]

# %% [markdown]
# ## Optimal strategies over increasing generations

# %%
with open(os.path.join(slide_data_dir, "N4A20_strategy_sweep_5_gens.pkl"), "rb") as f:
    gen5 = pickle.load(f).mean(axis=0)

with open(os.path.join(slide_data_dir, "N4A20_strategy_sweep_25_gens.pkl"), "rb") as f:
    gen25 = pickle.load(f).mean(axis=0)

with open(os.path.join(slide_data_dir, "N4A20_strategy_sweep_50_gens.pkl"), "rb") as f:
    gen50 = pickle.load(f).mean(axis=0)

with open(os.path.join(slide_data_dir, "N4A20_strategy_sweep_75_gens.pkl"), "rb") as f:
    gen75 = pickle.load(f).mean(axis=0)

with open(os.path.join(slide_data_dir, "N4A20_strategy_sweep_100_gens.pkl"), "rb") as f:
    gen100 = pickle.load(f).mean(axis=0)

with open(os.path.join(slide_data_dir, "N4A20_strategy_sweep_500_gens.pkl"), "rb") as f:
    gen500 = pickle.load(f).mean(axis=0)

with open(os.path.join(slide_data_dir, "N4A20_strategy_sweep_1000_gens.pkl"), "rb") as f:
    gen1000 = pickle.load(f).mean(axis=0)

# %%
combined = np.array([gen5, gen25, gen50, gen75, gen100, gen500, gen1000])
print(combined.shape)
# Out:
# (7, 3, 7, 7)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example: combined.shape = (5, 3, 7, 7)
# combined = np.array([gen5, gen25, gen50, gen75, gen100])

generations = [5, 25, 50, 75, 100,500, 1000]
ruggedness_labels = ['Smooth', 'Mid rugged', 'Rugged']  # adjust if needed
splits = np.array([24, 20, 16, 12, 8, 4, 1][::-1])  # your population split values

# Assuming base_chances are calculated like this:
thresholds, base_chances = base_chance_threshold_fixed_prop([0, 0.19], 0.2, 7)
base_chances = np.array(base_chances)  # should be shape (7,)

num_ruggedness = combined.shape[1]

# Arrays to store optimal values
optimal_splits_values = np.zeros((num_ruggedness, len(generations)))
optimal_base_chances = np.zeros((num_ruggedness, len(generations)))

for i, gen_data in enumerate(combined):
    for j in range(num_ruggedness):
        # Find the (pop_split, base_chance) index that is maximal
        best_idx = np.unravel_index(np.argmax(gen_data[j], axis=None), gen_data[j].shape)
        pop_split_idx, base_chance_idx = best_idx
        
        # Map to actual split and base chance
        optimal_splits_values[j, i] = splits[pop_split_idx]
        optimal_base_chances[j, i] = base_chances[base_chance_idx]


# Plotting
fig, ax1 = plt.subplots(figsize=(8,5))

# Plot optimal splits
for j in range(num_ruggedness):
    ax1.plot(generations, optimal_splits_values[j],label=f'Splits: {ruggedness_labels[j]}')

ax1.set_xlabel('Generations')
ax1.set_ylabel('Optimal Population Splits')
ax1.set_xticks(generations)
ax1.set_ylim(min(splits)-max(splits)*0.1, max(splits)*1.1)

# Secondary axis for base chances
ax2 = ax1.twinx()
for j in range(num_ruggedness):
    ax2.plot(generations, optimal_base_chances[j], linestyle='--', label=f'Base Chance: {ruggedness_labels[j]}')

ax2.set_ylabel('Optimal Base Chance')
ax2.set_ylim(0-max(base_chances)*0.1, max(base_chances)*1.1)

# Combine legends
lines_labels = [ax.get_legend_handles_labels() for ax in [ax1, ax2]]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
ax1.legend(lines, labels, loc='upper right')

plt.title('Optimal Population Splits and Base Chances vs Generations')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example: combined.shape = (5, 3, 7, 7)
# combined = np.array([gen5, gen25, gen50, gen75, gen100])

generations = [5, 25, 50, 75, 100]
ruggedness_labels = ['Low', 'Medium', 'High']  # adjust as needed
num_ruggedness = combined.shape[1]

# Initialize an array to store optimal population split for each ruggedness and generation
optimal_splits = np.zeros((num_ruggedness, len(generations)))

# Loop over generations and ruggedness
for i, gen_data in enumerate(combined):
    for j in range(num_ruggedness):
        # Sum over base chance axis (axis=1) to get a score for each population split
        pop_split_scores = gen_data[j].sum(axis=1)  # shape (7,)
        # Optimal population split is the index of the max
        optimal_splits[j, i] = np.argmax(pop_split_scores)

# Plotting
plt.figure(figsize=(8, 5))
for j in range(num_ruggedness):
    plt.plot(generations, optimal_splits[j], marker='o', label=f'Ruggedness: {ruggedness_labels[j]}')

plt.xlabel('Generations')
plt.ylabel('Optimal Population Split')
plt.ylim(0, 6)  # population splits 0 to 6
plt.xticks(generations)
plt.title('Optimal Population Splits vs Generations for Each Landscape Ruggedness')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Looking into a selection of "WT" start points

# %%
def strategy_from_decay(decay_rate, standard_decay_rates = decay_rates, optimal_base_chances = optimal_base_chances, optimal_splits = optimal_splits):
    
    optimum_index = np.argmin(np.abs(standard_decay_rates - decay_rate))
    
    return optimal_base_chances[optimum_index], optimal_splits[optimum_index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 def strategy_from_decay(decay_rate, standard_decay_rates = decay_rates, optimal_base_chances = optimal_base_chances, optimal_splits = optimal_splits):
#       3     optimum_index = np.argmin(np.abs(standard_decay_rates - decay_rate))
#       5     return optimal_base_chances[optimum_index], optimal_splits[optimum_index]
#
# NameError: name 'decay_rates' is not defined

# %%
with open(os.path.join(slide_data_dir, "GB1_mid_fitness_sweep_100.pkl"), "rb") as f:
    GB1_mf_strategy = pickle.load(f)

with open(os.path.join(slide_data_dir, "decay_curves_gb1_mid_fitness_100.pkl"), "rb") as f:
    GB1_mf_curves = pickle.load(f)

# %%
GB1_mf_strategy_mean = GB1_mf_strategy.mean(axis=(3))
GB1_mf_curves_mean = GB1_mf_curves.mean(axis=(0,2))
decay_rates = [get_single_decay_rate(decay_mean,mut=0.1) for decay_mean in GB1_mf_curves_mean]
strategies = [strategy_from_decay(decay_rate[0]) for decay_rate in decay_rates]

# %%
row_idx = np.unravel_index(
    np.argmax(GB1_mf_strategy_mean.reshape(100, -1), axis=1),
    (7, 7)
)[0]

# %%
true_splits = [splits[i] for i in row_idx]
chosen_splits = [i[1] for i in strategies]

# %%
plt.scatter(true_splits, chosen_splits)

# %%
np.where(np.array(splits) == 24)[0][0]
# Out:
# np.int64(0)

# %%
strategy[1]
# Out:
# 16

# %%
base_chances
# Out:
# Array([0.        , 0.03166667, 0.06333333, 0.095     , 0.12666667,
#        0.15833333, 0.19      ], dtype=float32)

# %%
np.where(np.array(base_chances) == strategy[0])
# Out:
# (array([0]),)

# %%
fig, axes = plt.subplots(
    10, 2, figsize=(6, 20), constrained_layout=True,dpi=200
)

for row, (space, curve, decay, strategy) in enumerate(
        zip(GB1_mf_strategy_mean,
            GB1_mf_curves_mean,
            decay_rates,
            strategies)):

    ax1 = axes[row, 0]
    ax2 = axes[row, 1]

    # ---- Left: curve ----
    ax1.plot(curve)
    ax1.set_title(f"rho = {decay[0]}", fontsize=7)
    ax1.tick_params(labelsize=6)

    # ---- Right: strategy space ----
    space = space[::-1, :]  # flip rows

    im = ax2.imshow(space)
    ax2.set_xticks([0, 6])
    ax2.set_xticklabels([0.0, 0.19], fontsize=6)
    ax2.set_yticks([0, 6])
    ax2.set_yticklabels([24, 1], fontsize=6)

    ax2.set_xlabel('Base chance', fontsize=6)
    ax2.set_ylabel('No. sub populations', fontsize=6)
    ax2.set_title('Strategy space', fontsize=7)

    # ---- Highlight selected strategy ----
    x = np.where(np.array(base_chances) == strategy[0])[0][0]
    orig_y = np.where(np.array(splits) == strategy[1])[0][0]
    y = len(splits) - 1 - orig_y


    ax2.scatter(x, y, c='white', s=20, edgecolors='black')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[141], line 11
#       1 fig, axes = plt.subplots(
#       2     10, 2, figsize=(6, 20), constrained_layout=True,dpi=200
#       3 )
#       5 for row, (space, curve, decay, strategy) in enumerate(
#       6         zip(GB1_mf_strategy_mean,
#       7             GB1_mf_curves_mean,
#       8             decay_rates,
#       9             strategies)):
# ---> 11     ax1 = axes[row, 0]
#      12     ax2 = axes[row, 1]
#      14     # ---- Left: curve ----
#
# IndexError: index 10 is out of bounds for axis 0 with size 10

# %%
for space, curve, decay, strategy in zip(
        GB1_mf_strategy_mean,
        GB1_mf_curves_mean,
        decay_rates,
        strategies):

    fig, (ax1, ax2) = plt.subplots(
        1, 2, figsize=(6, 3), constrained_layout=True
    )

    # ---- Left: curve ----
    ax1.plot(curve)
    ax1.set_title(f"rho = {decay[0]}", fontsize=7)
    ax1.tick_params(labelsize=6)

    # ---- Right: strategy space ----
    space = space[::-1, :]  # flip rows

    im = ax2.imshow(space)
    ax2.set_xticks([0, 6])
    ax2.set_xticklabels([0.0, 0.19], fontsize=6)
    ax2.set_yticks([0, 6])
    ax2.set_yticklabels([24, 1], fontsize=6)

    ax2.set_xlabel('Base chance', fontsize=6)
    ax2.set_ylabel('No. sub populations', fontsize=6)
    ax2.set_title('Strategy space', fontsize=7)

    # highlight selected strategy
    x = np.where(np.array(base_chances) == strategy[0])[0][0]
    y = np.where(np.array(splits) == strategy[1])[0][0]

    ax2.scatter(x, y, c='white', s=20, edgecolors='black')

    plt.show()

# %%
for space, curve, decay, strategy in zip(GB1_mf_strategy_mean, GB1_mf_curves_mean, decay_rates, strategies):

    plt.plot(curve)
    plt.title(f"rho = {decay[0]}")
    plt.show()

    space = space[::-1, :]
    plt.imshow(i)
    plt.xticks([0, 6], labels=[0.0, 0.19])
    plt.yticks([0, 6], labels=[24, 1])
    plt.ylabel('No. sub populations', fontsize=6)
    plt.xlabel('Base chance', fontsize=6)
    plt.title('Strategy space', fontsize=6)
    plt.tick_params(axis='both', which='major', labelsize=5)
    plt.scatter(np.where(np.array(base_chances) == strategy[0]), np.where(np.array(splits) == strategy[1])[0][0])
    plt.show()

# %%
GB1_mf_strategy_mean = GB1_mf_strategy.mean(axis=(3))

# %%
for i in GB1_mf_strategy_mean:
    i = i[::-1, :]
    plt.imshow(i)
    plt.xticks([0, 6], labels=[0.0, 0.19])
    plt.yticks([0, 6], labels=[24, 1])
    plt.ylabel('No. sub populations', fontsize=6)
    plt.xlabel('Base chance', fontsize=6)
    plt.title('Strategy space', fontsize=6)
    plt.tick_params(axis='both', which='major', labelsize=5)
    plt.show()
